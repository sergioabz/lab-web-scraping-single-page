# %% [markdown]
# # Lab | Not hot songs

# %% [markdown]
# **Prepare a new dataset of not_hot_songs. This dataset can contain songs of your choice, others collected from the web or any other combination**

# %%
# 1. import libraries
from bs4 import BeautifulSoup
import requests
import pandas as pd

# 2. Explore the dataset

songs_file = pd.read_csv('Spotify_Top_Hit_Playlist_2010_2022.csv')
songs_file.head()


# Dataset taken from: https://www.kaggle.com/datasets/josephinelsy/spotify-top-hit-playlist-2010-2022
# Out:
#                                         playlist_url  year  \
# 0  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 1  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 2  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 3  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 4  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
#
#                  track_id            track_name  track_popularity  \
# 0  3AJwUDP919kvQ9QcozQPxg                Yellow                91
# 1  2m1hi0nfMR9vdGC8UcrnwU  All The Small Things                84
# 2  3y4LxiYMgDl4RethdzpmNe               Breathe                69
# 3  60a0Rd6pjrkxjPbaKzXjfq            In the End                88
# 4  62bOmKYxYg7dhrC6gH9vFn           Bye Bye Bye                74
#
#                            album               artist_id  artist_name  \
# 0                     Parachutes  4gzpq5DPGxSnKTe4SA8HAU     Coldplay
# ...

# %%
# Create a new DataFrame with columns "track_name" as Title an "artist_name" as Artist

not_hot_songs = pd.DataFrame().assign(Title=songs_file['track_name'], Artist=songs_file['artist_name'])
not_hot_songs.head()
# Out:
#                   Title       Artist
# 0                Yellow     Coldplay
# 1  All The Small Things    blink-182
# 2               Breathe   Faith Hill
# 3            In the End  Linkin Park
# 4           Bye Bye Bye       *NSYNC

# %%
#Get DF ino

not_hot_songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2300 entries, 0 to 2299
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Title   2300 non-null   object
#  1   Artist  2300 non-null   object
# dtypes: object(2)
# memory usage: 36.1+ KB

# %%
# Read the "hot_songs.csv" to merge the DataFrame and look for duplicates 

hot_songs = pd.read_csv('hot_songs.csv')
hot_songs.head()
# Out:
#                    Title                                Artist
# 0     Paint The Town Red                              Doja Cat
# 1                 Snooze                                   SZA
# 2               Fast Car                            Luke Combs
# 3           Cruel Summer                          Taylor Swift
# 4  I Remember Everything  Zach Bryan Featuring Kacey Musgraves

# %%
# Hot_songs shape

hot_songs.shape
# Out:
# (100, 2)

# %%
# Merge both DataFrame

duplicates = pd.concat([hot_songs, not_hot_songs], axis=1)

# %%
duplicates.head()
# Out:
#                    Title                                Artist  \
# 0     Paint The Town Red                              Doja Cat
# 1                 Snooze                                   SZA
# 2               Fast Car                            Luke Combs
# 3           Cruel Summer                          Taylor Swift
# 4  I Remember Everything  Zach Bryan Featuring Kacey Musgraves
#
#                   Title       Artist
# 0                Yellow     Coldplay
# 1  All The Small Things    blink-182
# 2               Breathe   Faith Hill
# 3            In the End  Linkin Park
# 4           Bye Bye Bye       *NSYNC

# %%
duplicates.shape
# Out:
# (2300, 4)

# %%
# Look for missing values

duplicates.isna().sum()
# Out:
# Title     2200
# Artist    2200
# Title        0
# Artist       0
# dtype: int64

# %%
# Search for duplicate values between the two DataFrame's

duplicates1 = hot_songs.merge(not_hot_songs, how='inner', on='Title')
duplicates1
# Out:
#            Title       Artist_x         Artist_y
# 0       Fast Car     Luke Combs       Jonas Blue
# 1       Fast Car     Luke Combs       Jonas Blue
# 2   Cruel Summer   Taylor Swift     Taylor Swift
# 3     Last Night  Morgan Wallen     Keyshia Cole
# 4      Anti-Hero   Taylor Swift     Taylor Swift
# 5       Daylight  David Kushner         Maroon 5
# 6  One More Time      Blink-182        Daft Punk
# 7          Crazy       Rod Wave   Gnarls Barkley
# 8         Demons       Doja Cat  Imagine Dragons

# %% [markdown]
# We have found two duplicate song + artist titles (Cruel Summer and Anti-Hero from Taylor Swift), we will remove them from the DataFrame "not_hot_songs".

# %%
# Drop the two duplicate songs

not_hot_songs1 = not_hot_songs.copy().set_index('Title')

# %%
# Drop the two duplicate songs

not_hot_songs1 = not_hot_songs1.drop(["Cruel Summer", "Anti-Hero"])

# %%
# Display new data frame without duplicates

not_hot_songs1.head()
# Out:
#                            Artist
# Title
# Yellow                   Coldplay
# All The Small Things    blink-182
# Breathe                Faith Hill
# In the End            Linkin Park
# Bye Bye Bye                *NSYNC

# %%
# check that the song has been removed

result = not_hot_songs1.loc["Cruel Summer"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:171, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:214, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:222, in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# ...

# %%
# check that the song has been removed

result = not_hot_songs1.loc["Anti-Hero"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:171, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:214, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:222, in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# ...

# %%
not_hot_songs1
# Out:
#                                      Artist
# Title
# Yellow                             Coldplay
# All The Small Things              blink-182
# Breathe                          Faith Hill
# In the End                      Linkin Park
# Bye Bye Bye                          *NSYNC
# ...                                     ...
# Die Hard                     Kendrick Lamar
# Big Energy                            Latto
# Doja                            Central Cee
# pushin P (feat. Young Thug)           Gunna
# Thousand Miles                The Kid LAROI
#
# [2298 rows x 1 columns]

# %%
#Save the final DataFrame
not_hot_songs1.to_csv('not_hot_song.csv', index=False)
